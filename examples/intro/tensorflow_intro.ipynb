# %% [markdown]
# <a href="https://colab.research.google.com/github/adammoss/MLiS2/blob/master/examples/intro/tensorflow_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np

# %%
tf.random.set_seed(1)

# %%
print(tf.__version__)
# Out:
# 2.4.1

# %%
X = np.array([[0,0], [0,1], [1,0], [1,1]])
print(X)
# Out:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]

# %%
Y = np.array([[0], [1], [1], [0]])
print(Y)
# Out:
# [[0]
#  [1]
#  [1]
#  [0]]

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(2, activation='relu', input_shape=[X.shape[1]]),
    layers.Dense(1)
  ])

  optimizer = keras.optimizers.RMSprop(0.01)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 2)                 6
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 3
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 300

# %%
model.fit(X, Y, epochs=num_epochs, verbose=1)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 677ms/step - loss: 0.5845 - mae: 0.5698 - mse: 0.5845
# Epoch 2/300
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5196 - mae: 0.5317 - mse: 0.5196
# Epoch 3/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4786 - mae: 0.5070 - mse: 0.4786
# Epoch 4/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4471 - mae: 0.4940 - mse: 0.4471
# Epoch 5/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4208 - mae: 0.4906 - mse: 0.4208
# Epoch 6/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3982 - mae: 0.4872 - mse: 0.3982
# Epoch 7/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3781 - mae: 0.4840 - mse: 0.3781
# Epoch 8/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3601 - mae: 0.4808 - mse: 0.3601
# Epoch 9/300
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3438 - mae: 0.4778 - mse: 0.3438
# ...

# %%
plt.plot(model.history.history['loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
model.predict(X)
# Out:
# array([[0.00513699],
#        [1.0193533 ],
#        [1.019116  ],
#        [0.00513699]], dtype=float32)
