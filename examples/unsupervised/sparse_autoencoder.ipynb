# %% [markdown]
# <a href="https://colab.research.google.com/github/adammoss/MLiS2/blob/master/examples/unsupervised/sparse_autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt

# %%
tf.random.set_seed(1)

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
class Encoder(layers.Layer):
  def __init__(self, hidden_dim):  
    super(Encoder, self).__init__()
    self.hidden_layer = layers.Dense(units=hidden_dim, activation=tf.nn.relu, activity_regularizer=keras.regularizers.l1(10e-5))
  def call(self, x):
    x = self.hidden_layer(x)
    return x

# %%
class Decoder(layers.Layer):
  def __init__(self, data_dim):
    super(Decoder, self).__init__()
    self.output_layer = layers.Dense(units=data_dim, activation=tf.nn.relu)
  def call(self, x):
    x = self.output_layer(x)
    return x

# %%
class Autoencoder(tf.keras.Model):
  def __init__(self, data_dim, hidden_dim):
    super(Autoencoder, self).__init__()
    self.encoder = Encoder(hidden_dim)
    self.decoder = Decoder(data_dim)
  def call(self, x):
    x = self.encoder(x)
    x = self.decoder(x)
    return x

# %%
(X_train, Y_train), (X_test, Y_test) =  tf.keras.datasets.mnist.load_data()
X_train = X_train/ 255
X_test = X_test/ 255
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1] * X_train.shape[2])).astype(np.float32)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1] * X_test.shape[2])).astype(np.float32)

# %%
autoencoder = Autoencoder(X_train.shape[1], 100)

# %%
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.build(X_train.shape)
autoencoder.summary()
# Out:
# Model: "autoencoder_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_1 (Encoder)          multiple                  78500
# _________________________________________________________________
# decoder_1 (Decoder)          multiple                  79184
# =================================================================
# Total params: 157,684
# Trainable params: 157,684
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(X_train, X_train, epochs=30, batch_size=256)
# Out:
# Train on 60000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0325
# Epoch 2/30
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.0147
# Epoch 3/30
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0123
# Epoch 4/30
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0110
# Epoch 5/30
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0103
# Epoch 6/30
# 60000/60000 [==============================] - 2s 42us/sample - loss: 0.0097
# Epoch 7/30
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0092
# Epoch 8/30
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0089
# Epoch 9/30
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0086
# Epoch 10/30
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0083
# Epoch 11/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0081
# Epoch 12/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0079
# Epoch 13/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0078
# Epoch 14/30
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0076
# Epoch 15/30
# 60000/60000 [==============================] - 2s 42us/sample - loss: 0.0075
# Epoch 16/30
# 60000/60000 [==============================] - 2s 42us/sample - loss: 0.0074
# Epoch 17/30
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.0073
# Epoch 18/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0072
# Epoch 19/30
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.0071
# Epoch 20/30
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0070
# Epoch 21/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0070
# Epoch 22/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0069
# Epoch 23/30
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0068
# Epoch 24/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0068
# Epoch 25/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0067
# Epoch 26/30
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.0067
# Epoch 27/30
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0066
# Epoch 28/30
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0066
# Epoch 29/30
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.0065
# Epoch 30/30
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.0065

# %%
X_decoded = autoencoder.predict(X_test)

# %%
n = 10 
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(X_test[i].reshape(28, 28), cmap='viridis')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(X_decoded[i].reshape(28, 28), cmap='viridis')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
hidden_weights = autoencoder.encoder.hidden_layer.get_weights()

# %%
plt.figure(figsize=(10, 6))
plt.imshow(hidden_weights[0].T, cmap='viridis')
plt.colorbar(orientation='horizontal')
plt.show()
